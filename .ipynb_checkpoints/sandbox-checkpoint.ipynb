# %%
import pdftotext
import re
from pdfminer.converter import TextConverter

# %%
# !conda activate public_policy_env
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
print(pdfminer.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9be6875f15c0> in <module>
# ----> 1 print(pdfminer.__version__)
#
# NameError: name 'pdfminer' is not defined

# %%
pdfminer.high_level.extract_text('pdf2.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-4ec18c4a3672> in <module>
# ----> 1 pdfminer.high_level.extract_text('pdf2.pdf')
#
# AttributeError: module 'pdfminer' has no attribute 'high_level'

# %%
from io import StringIO
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

output_string = StringIO()
with open('pdf2.pdf', 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams(detect_vertical=True))
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)

print(output_string.getvalue())
# Out:
# AUTHOR ACCEPTED MANUSCRIPT
#
# FINAL PUBLICATION INFORMATION
#
# The Effects of Pollution and Business Environment on Firm Productivity in Africa
#
# The definitive version of the text was subsequently published in
#
# The Journal of Environment and Development, (forthcoming 2020), 2020
#
# Published by Sage Publications
#
# THE FINAL PUBLISHED VERSION OF THIS MANUSCRIPT
# IS AVAILABLE ON THE PUBLISHER’S PLATFORM
#
# This Author Accepted Manuscript is copyrighted by World Bank and published by Sage Publications. It is posted here
# by agreement between them. Changes resulting from the publishing process—such as editing, corrections, structural
# formatting, and other quality control mechanisms—may not be reflected in this version of the text.
#
# You may download, copy, and distribute this Author Accepted Manuscript for noncommercial purposes. Your license
# is limited by the following restrictions:
#
# ...

# %%
# Load PDF
with open("pdf3.pdf", "rb") as f:
    pdf = pdftotext.PDF(f)

full_text = "\n\n".join(pdf)
full_text = full_text.replace("\n",' ').lower()
full_text = re.split(r'[.] ',full_text)

# %%
check_string = 'GDP'

search_results = [sentence for sentence in full_text if check_string.lower() in sentence]

# %%
search_results
# Out:
# ['using the simple model, hertel and baldos dence of unconditional convergence after 1998 among the 67 lar-                              (2016, p.30) find that long-run crop prices will most likely resume gest economies that accounted for 96 percent of world gdp and                                their downward trend between 2006 and 2050 but that these 86 percent of world population',
#  'annual per capita gdp growth rates 1951–2018: developed versus developing countries, %',
#  'source: maddison (2010) data on gdp at 1990 ppp for 1950–2008 and world bank (2019) data at 2011 ppp for 2009-2017',
#  'past and future growth in global food demand     where y is ce consumption per capita and x is purchasing power parity (ppp) gross domestic product (gdp) per capita in 2005 con-                                in table 1, we decompose total growth in global food demand stant prices',
# ...
